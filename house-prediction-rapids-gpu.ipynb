# %% [markdown]
# ## House-Prices-Advanced-Regression-Techniques
#
# ### Made By: Gaurav Baweja

# %%
import cudf as pd
import cupy as np
import cuml as ml
from cuml.preprocessing.LabelEncoder import LabelEncoder
from cuml.model_selection import train_test_split
from cuml.metrics.regression import mean_squared_error,mean_absolute_error,r2_score

# %%
TRAIN_PATH = "../input/house-prices-advanced-regression-techniques/train.csv"
TEST_PATH = "../input/house-prices-advanced-regression-techniques/test.csv"
SAMPLE_SUBMISSION_PATH = "../input/house-prices-advanced-regression-techniques/sample_submission.csv"
SUBMISSION_PATH = "submission.csv"
ID = "Id"
TARGET = "SalePrice"
train = pd.read_csv(TRAIN_PATH)
test = pd.read_csv(TEST_PATH)
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave  <NA>      Reg
# 1   2          20       RL         80.0     9600   Pave  <NA>      Reg
# 2   3          60       RL         68.0    11250   Pave  <NA>      IR1
# 3   4          70       RL         60.0     9550   Pave  <NA>      IR1
# 4   5          60       RL         84.0    14260   Pave  <NA>      IR1
#
#   LandContour Utilities  ... PoolArea  PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    <NA>  <NA>        <NA>       0
# 1         Lvl    AllPub  ...        0    <NA>  <NA>        <NA>       0
# 2         Lvl    AllPub  ...        0    <NA>  <NA>        <NA>       0
# 3         Lvl    AllPub  ...        0    <NA>  <NA>        <NA>       0
# 4         Lvl    AllPub  ...        0    <NA>  <NA>        <NA>       0
#
#    MoSold  YrSold  SaleType SaleCondition SalePrice
# 0       2    2008        WD        Normal    208500
# 1       5    2007        WD        Normal    181500
# 2       9    2008        WD        Normal    223500
# 3       2    2006        WD       Abnorml    140000
# 4      12    2008        WD        Normal    250000
#
# [5 rows x 81 columns]

# %%
test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave  <NA>      Reg
# 1  1462          20       RL         81.0    14267   Pave  <NA>      IR1
# 2  1463          60       RL         74.0    13830   Pave  <NA>      IR1
# 3  1464          60       RL         78.0     9978   Pave  <NA>      IR1
# 4  1465         120       RL         43.0     5005   Pave  <NA>      IR1
#
#   LandContour Utilities  ... ScreenPorch  PoolArea  PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120         0    <NA>  MnPrv        <NA>
# 1         Lvl    AllPub  ...           0         0    <NA>   <NA>        Gar2
# 2         Lvl    AllPub  ...           0         0    <NA>  MnPrv        <NA>
# 3         Lvl    AllPub  ...           0         0    <NA>   <NA>        <NA>
# 4         HLS    AllPub  ...         144         0    <NA>   <NA>        <NA>
#
#   MiscVal  MoSold  YrSold  SaleType SaleCondition
# 0       0       6    2010        WD        Normal
# 1   12500       6    2010        WD        Normal
# 2       0       3    2010        WD        Normal
# 3       0       6    2010        WD        Normal
# 4       0       1    2010        WD        Normal
#
# [5 rows x 80 columns]

# %%
df = pd.concat([train.iloc[:,:-1],test]).reset_index(drop=True)
Y=train.iloc[:,-1].copy()
df
# Out:
#         Id  MSSubClass MSZoning LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL        65.0     8450   Pave  <NA>      Reg
# 1        2          20       RL        80.0     9600   Pave  <NA>      Reg
# 2        3          60       RL        68.0    11250   Pave  <NA>      IR1
# 3        4          70       RL        60.0     9550   Pave  <NA>      IR1
# 4        5          60       RL        84.0    14260   Pave  <NA>      IR1
# ...    ...         ...      ...         ...      ...    ...   ...      ...
# 2914  2915         160       RM        21.0     1936   Pave  <NA>      Reg
# 2915  2916         160       RM        21.0     1894   Pave  <NA>      Reg
# 2916  2917          20       RL       160.0    20000   Pave  <NA>      Reg
# 2917  2918          85       RL        62.0    10441   Pave  <NA>      Reg
# 2918  2919          60       RL        74.0     9627   Pave  <NA>      Reg
#
#      LandContour Utilities  ... ScreenPorch  PoolArea  PoolQC  Fence  \
# 0            Lvl    AllPub  ...           0         0    <NA>   <NA>
# 1            Lvl    AllPub  ...           0         0    <NA>   <NA>
# 2            Lvl    AllPub  ...           0         0    <NA>   <NA>
# 3            Lvl    AllPub  ...           0         0    <NA>   <NA>
# 4            Lvl    AllPub  ...           0         0    <NA>   <NA>
# ...          ...       ...  ...         ...       ...     ...    ...
# 2914         Lvl    AllPub  ...           0         0    <NA>   <NA>
# 2915         Lvl    AllPub  ...           0         0    <NA>   <NA>
# 2916         Lvl    AllPub  ...           0         0    <NA>   <NA>
# 2917         Lvl    AllPub  ...           0         0    <NA>  MnPrv
# 2918         Lvl    AllPub  ...           0         0    <NA>   <NA>
#
#      MiscFeature MiscVal  MoSold  YrSold  SaleType SaleCondition
# 0           <NA>       0       2    2008        WD        Normal
# 1           <NA>       0       5    2007        WD        Normal
# 2           <NA>       0       9    2008        WD        Normal
# 3           <NA>       0       2    2006        WD       Abnorml
# 4           <NA>       0      12    2008        WD        Normal
# ...          ...     ...     ...     ...       ...           ...
# 2914        <NA>       0       6    2006        WD        Normal
# 2915        <NA>       0       4    2006        WD       Abnorml
# 2916        <NA>       0       9    2006        WD       Abnorml
# 2917        Shed     700       7    2006        WD        Normal
# 2918        <NA>       0      11    2006        WD        Normal
#
# [2919 rows x 80 columns]

# %%
def Preprocessing1(df,cols=1):
    if cols>0:
        df_cp = df.copy()
        pca = ml.PCA(n_components=cols,output_type='cudf')
        pca.fit(df_cp)
        df_cp = pca.transform(df_cp)
        return df_cp
    return df

# %%
def checkNull_fillData(df):
    na_cols=[]
    for col in df.columns:
        if df[col].isna().sum()>0.2*len(df):
            na_cols.append(col)
    df = df.drop(na_cols,axis=1)
    na_cols=[]
    for col in df.select_dtypes(exclude='object').columns:
        if(df[col]==0).sum()>0.2*len(df):
            na_cols.append(col)
    df=df.drop(na_cols,axis=1)
    df=df.drop('Id',axis=1)
    for col in df.select_dtypes(include='object').columns:
        df[col]=df[col].fillna(df[col].mode()[0],inplace=False)
    for col in df.select_dtypes(exclude='object').columns:
        df[col]=df[col].fillna(df[col].mean(),inplace=False)
    return df
df = checkNull_fillData(df)

# %%
#Encodeing
def encodeData(df):
    for col in df.select_dtypes(include='object').columns:
        encode = LabelEncoder()
        df[col]=pd.Series(encode.fit_transform(df[col]))
    return df
df = encodeData(df)
df
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0             60         3         65.0     8450       1         3
# 1             20         3         80.0     9600       1         3
# 2             60         3         68.0    11250       1         0
# 3             70         3         60.0     9550       1         0
# 4             60         3         84.0    14260       1         0
# ...          ...       ...          ...      ...     ...       ...
# 2914         160         4         21.0     1936       1         3
# 2915         160         4         21.0     1894       1         3
# 2916          20         3        160.0    20000       1         3
# 2917          85         3         62.0    10441       1         3
# 2918          60         3         74.0     9627       1         3
#
#       LandContour  Utilities  LotConfig  LandSlope  ...  GarageFinish  \
# 0               3          0          4          0  ...             1
# 1               3          0          2          0  ...             1
# 2               3          0          4          0  ...             1
# 3               3          0          0          0  ...             2
# 4               3          0          2          0  ...             1
# ...           ...        ...        ...        ...  ...           ...
# 2914            3          0          4          0  ...             2
# 2915            3          0          4          0  ...             2
# 2916            3          0          4          0  ...             2
# 2917            3          0          4          0  ...             2
# 2918            3          0          4          1  ...             0
#
#       GarageCars  GarageArea  GarageQual  GarageCond  PavedDrive  MoSold  \
# 0            2.0       548.0           4           4           2       2
# 1            2.0       460.0           4           4           2       5
# 2            2.0       608.0           4           4           2       9
# 3            3.0       642.0           4           4           2       2
# 4            3.0       836.0           4           4           2      12
# ...          ...         ...         ...         ...         ...     ...
# 2914         0.0         0.0           4           4           2       6
# 2915         1.0       286.0           4           4           2       4
# 2916         2.0       576.0           4           4           2       9
# 2917         0.0         0.0           4           4           2       7
# 2918         3.0       650.0           4           4           2      11
#
#       YrSold  SaleType  SaleCondition
# 0       2008         8              4
# 1       2007         8              4
# 2       2008         8              4
# 3       2006         8              0
# 4       2008         8              4
# ...      ...       ...            ...
# 2914    2006         8              4
# 2915    2006         8              0
# 2916    2006         8              0
# 2917    2006         8              4
# 2918    2006         8              4
#
# [2919 rows x 58 columns]

# %%
#Scaling the Data ( YEO-JOHNSON TRANFORMATION(0),Z-Score)
for col in df.columns:
    if 0 in df[col].unique():
        a = df[col].mean()
        b = df[col].std()
        df[col]=df[col].applymap(lambda x:(x-a)/b)
    else:
        encode = PowerTransform()
        encode.fit(df[col].values.get().reshape(-1,-1))
        a=encode.transform(df[col].values.get().reshape(-1,-1))
        df[col]=pd.Series(a.flatten())
df
# Out:
#       MSSubClass  MSZoning  LotFrontage     LotArea    Street  LotShape  \
# 0       0.067320 -0.042149    -0.202033  197.397238 -3.080024 -0.042149
# 1      -0.873466 -0.042149     0.501785  224.444843 -3.080024 -0.042149
# 2       0.067320 -0.042149    -0.061269  263.252276 -3.080024 -4.598962
# 3       0.302516 -0.042149    -0.436639  223.268860 -3.080024 -4.598962
# 4       0.067320 -0.042149     0.689469  334.046442 -3.080024 -4.598962
# ...          ...       ...          ...         ...       ...       ...
# 2914    2.419286  1.476788    -2.266564   44.190195 -3.080024 -0.042149
# 2915    2.419286  1.476788    -2.266564   43.202370 -3.080024 -0.042149
# 2916   -0.873466 -0.042149     4.255477  469.049270 -3.080024 -0.042149
# 2917    0.655311 -0.042149    -0.342796  244.224874 -3.080024 -0.042149
# 2918    0.067320 -0.042149     0.220258  225.079873 -3.080024 -0.042149
#
#       LandContour  Utilities  LotConfig  LandSlope  ...  GarageFinish  \
# 0       -0.042149  -4.598962   1.476788  -4.598962  ...     -3.080024
# 1       -0.042149  -4.598962  -1.561087  -4.598962  ...     -3.080024
# 2       -0.042149  -4.598962   1.476788  -4.598962  ...     -3.080024
# 3       -0.042149  -4.598962  -4.598962  -4.598962  ...     -1.561087
# 4       -0.042149  -4.598962  -1.561087  -4.598962  ...     -3.080024
# ...           ...        ...        ...        ...  ...           ...
# 2914    -0.042149  -4.598962   1.476788  -4.598962  ...     -1.561087
# 2915    -0.042149  -4.598962   1.476788  -4.598962  ...     -1.561087
# 2916    -0.042149  -4.598962   1.476788  -4.598962  ...     -1.561087
# 2917    -0.042149  -4.598962   1.476788  -4.598962  ...     -1.561087
# 2918    -0.042149  -4.598962   1.476788  -3.080024  ...     -4.598962
#
#       GarageCars  GarageArea  GarageQual  GarageCond  PavedDrive    MoSold  \
# 0      -3.158066   22.460888    1.476788    1.476788   -1.561087 -1.296820
# 1      -3.158066   18.331826    1.476788    1.476788   -1.561087 -1.226261
# 2      -3.158066   25.276158    1.476788    1.476788   -1.561087 -1.132183
# 3      -3.111145   26.871477    1.476788    1.476788   -1.561087 -1.296820
# 4      -3.111145   35.974182    1.476788    1.476788   -1.561087 -1.061624
# ...          ...         ...         ...         ...         ...       ...
# 2914   -3.251908   -3.251908    1.476788    1.476788   -1.561087 -1.202742
# 2915   -3.204987   10.167544    1.476788    1.476788   -1.561087 -1.249781
# 2916   -3.158066   23.774681    1.476788    1.476788   -1.561087 -1.132183
# 2917   -3.251908   -3.251908    1.476788    1.476788   -1.561087 -1.179222
# 2918   -3.111145   27.246846    1.476788    1.476788   -1.561087 -1.085143
#
#          YrSold  SaleType  SaleCondition
# 0     45.883611  7.552538       1.476788
# 1     45.860091  7.552538       1.476788
# 2     45.883611  7.552538       1.476788
# 3     45.836571  7.552538      -4.598962
# 4     45.883611  7.552538       1.476788
# ...         ...       ...            ...
# 2914  45.836571  7.552538       1.476788
# 2915  45.836571  7.552538      -4.598962
# 2916  45.836571  7.552538      -4.598962
# 2917  45.836571  7.552538       1.476788
# 2918  45.836571  7.552538       1.476788
#
# [2919 rows x 58 columns]

# %%
#Split Data
df_train = df.iloc[:1460,:]
df_train[TARGET] = Y
df_test = df.iloc[1460:,:]
df_train
# Out:
#       MSSubClass  MSZoning  LotFrontage     LotArea    Street  LotShape  \
# 0       0.067320 -0.042149    -0.202033  197.397238 -3.080024 -0.042149
# 1      -0.873466 -0.042149     0.501785  224.444843 -3.080024 -0.042149
# 2       0.067320 -0.042149    -0.061269  263.252276 -3.080024 -4.598962
# 3       0.302516 -0.042149    -0.436639  223.268860 -3.080024 -4.598962
# 4       0.067320 -0.042149     0.689469  334.046442 -3.080024 -4.598962
# ...          ...       ...          ...         ...       ...       ...
# 1455    0.067320 -0.042149    -0.342796  184.861261 -3.080024 -0.042149
# 1456   -0.873466 -0.042149     0.736390  308.527614 -3.080024 -0.042149
# 1457    0.302516 -0.042149    -0.155112  211.320874 -3.080024 -0.042149
# 1458   -0.873466 -0.042149    -0.061269  227.196642 -3.080024 -0.042149
# 1459   -0.873466 -0.042149     0.267179  232.370967 -3.080024 -0.042149
#
#       LandContour  Utilities  LotConfig  LandSlope  ...  GarageCars  \
# 0       -0.042149  -4.598962   1.476788  -4.598962  ...   -3.158066
# 1       -0.042149  -4.598962  -1.561087  -4.598962  ...   -3.158066
# 2       -0.042149  -4.598962   1.476788  -4.598962  ...   -3.158066
# 3       -0.042149  -4.598962  -4.598962  -4.598962  ...   -3.111145
# 4       -0.042149  -4.598962  -1.561087  -4.598962  ...   -3.111145
# ...           ...        ...        ...        ...  ...         ...
# 1455    -0.042149  -4.598962   1.476788  -4.598962  ...   -3.158066
# 1456    -0.042149  -4.598962   1.476788  -4.598962  ...   -3.158066
# 1457    -0.042149  -4.598962   1.476788  -4.598962  ...   -3.204987
# 1458    -0.042149  -4.598962   1.476788  -4.598962  ...   -3.204987
# 1459    -0.042149  -4.598962   1.476788  -4.598962  ...   -3.204987
#
#       GarageArea  GarageQual  GarageCond  PavedDrive    MoSold     YrSold  \
# 0      22.460888    1.476788    1.476788   -1.561087 -1.296820  45.883611
# 1      18.331826    1.476788    1.476788   -1.561087 -1.226261  45.860091
# 2      25.276158    1.476788    1.476788   -1.561087 -1.132183  45.883611
# 3      26.871477    1.476788    1.476788   -1.561087 -1.296820  45.836571
# 4      35.974182    1.476788    1.476788   -1.561087 -1.061624  45.883611
# ...          ...         ...         ...         ...       ...        ...
# 1455   18.331826    1.476788    1.476788   -1.561087 -1.155702  45.860091
# 1456   20.208672    1.476788    1.476788   -1.561087 -1.296820  45.930650
# 1457    8.572224    1.476788    1.476788   -1.561087 -1.226261  45.930650
# 1458    8.009170    1.476788    1.476788   -1.561087 -1.249781  45.930650
# 1459    9.698332    1.476788    1.476788   -1.561087 -1.202742  45.883611
#
#       SaleType  SaleCondition  SalePrice
# 0     7.552538       1.476788     208500
# 1     7.552538       1.476788     181500
# 2     7.552538       1.476788     223500
# 3     7.552538      -4.598962     140000
# 4     7.552538       1.476788     250000
# ...        ...            ...        ...
# 1455  7.552538       1.476788     175000
# 1456  7.552538       1.476788     210000
# 1457  7.552538       1.476788     266500
# 1458  7.552538       1.476788     142125
# 1459  7.552538       1.476788     147500
#
# [1460 rows x 59 columns]

# %%
X = df_train.iloc[:,:-1].values
y = np.log(df_train.iloc[:,-1])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,random_state=42)
y_train, y_test = y_train.astype('float64'), y_test.astype('float64')

# %%
algorithm = ['svd', 'eig', 'qr', 'svd-qr', 'svd-jacobi']
MSE=[]
R2_Score=[]
MAE =[]
for alg in algorithm:
    lr = ml.LinearRegression( algorithm = alg)
    lr.fit(X_train,y_train)
    predict = lr.predict(X_test)
    MSE.append(mean_squared_error(y_test,predict))
    R2_Score.append(r2_score(y_test,predict))
    MAE.append(mean_absolute_error(y_test,predict))

# %%
res = pd.DataFrame(index = algorithm)
res['R2_Score']=R2_Score
res['MSE']=MSE
res['MAE']=MAE
res
# Out:
#             R2_Score       MSE       MAE
# svd         0.878530  0.019515  0.099939
# eig         0.878530  0.019515  0.099939
# qr          0.878530  0.019515  0.099939
# svd-qr     -0.061305  0.170507  0.324293
# svd-jacobi -0.061305  0.170507  0.324293

# %%
#Best Model is Linear Regression-SVD
reg = ml.LinearRegression( algorithm = 'svd')
reg.fit(X_train,y_train)
y_pred = reg.predict(X_test)
print('R2_Score: ',r2_score(y_test,y_pred),'\tMAE: ',mean_absolute_error(y_test,y_pred),'\tMSE: ',mean_squared_error(y_test,y_pred))
# Out:
# R2_Score:  -0.061305124684885914 	MAE:  0.32429276404785695 	MSE:  0.17050735817739998

# %%
#Prediciton on Test Data
ids=pd.Series(df_test.index+1)
sub = pd.DataFrame()
sub[ID] = ids
sub[TARGET] = reg.predict(df_test)
sub[TARGET]=np.exp(sub[TARGET],dtype='float64')
sub.to_csv(SUBMISSION_PATH,index=False)
sub
# Out:
#         Id      SalePrice
# 0     1461  168060.192639
# 1     1462  162184.183244
# 2     1463  162313.159045
# 3     1464  159705.584143
# 4     1465  164857.729745
# ...    ...            ...
# 1454  2915  182532.749092
# 1455  2916  178561.316117
# 1456  2917  168602.542119
# 1457  2918  201919.679635
# 1458  2919  175761.003015
#
# [1459 rows x 2 columns]
